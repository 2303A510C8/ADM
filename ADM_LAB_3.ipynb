# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A510C8/23CSBTB-27/blob/main/ADM_LAB_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0,6])
ypoints = np.array([0,250])
plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0, 6])
plt.plot(xpoints)
ypoints = np.array([0, 250])
plt.plot( ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3,8,1,10])
plt.plot(ypoints)
plt.show()

# %%
ypoints = np.array([3,8,1,10])
plt.plot(ypoints,'o')
plt.show()

# %%
ypoints = np.array([3,8,1,10,8,9])
plt.plot(ypoints,"o:r")
plt.show()

# %%
plt.plot(ypoints,1s = 'o')
plt.plot(ypoint,color = 'r')
plt.()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1=np.array([0,1,2,3])
y1=np.array([3,8,1,10])
x2=np.array([0,1,2,3])
y2=np.array([6,2,7,11])

plt.plot(x1,y1,x2,y2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints=np.array([3,8,1,10,5,7])

plt.plot(ypoints,marker='o',ms=20,mec='royalblue',mfc='yellow')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A","B","C","D"])
y = np.array([3,8,1,10])

plt.bar(x,y)
plt.show()

# %%
plt.plot(x,y)

plt.title("Sports Watch Data ")
plt.xlabel("Average Pulse")
plt.ylabel("Caloire Burnage")
plt.show()

# %%
plt.grid()
plt.grid(axis = 'x')
plt.grid(axis = 'y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.random.normal(170,10,250)
plt.hist(x)
plt.show()

# %%
x1=np.array([0,1,2,3])
y1=np.array([3,8,1,10])
plt.subplot(2,1,1)
plt.plot(x1,y1)
x2=np.array([0,1,2,3])
y2=np.array([10,1,6,8])
plt.subplot(2,1,2)
plt.plot(x2,y2)
plt.show()
